# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = np.random.normal(loc=3, scale=1, size=100)
df
# Out:
# array([3.57226585, 2.97803452, 2.5363949 , 2.88242488, 3.67522466,
#        2.01729834, 2.44126604, 2.54786275, 2.13309909, 3.4418607 ,
#        3.53651052, 2.62140555, 2.75902541, 2.38102937, 2.45123691,
#        2.24425171, 2.0600976 , 3.95123701, 3.62834112, 1.58237145,
#        3.46336958, 1.66949525, 0.97064906, 3.38644559, 3.49026864,
#        3.06147027, 4.18829086, 2.4145103 , 5.00131694, 0.19378941,
#        3.33935179, 2.33255159, 3.00246761, 4.89407766, 3.44799996,
#        3.15662079, 2.88060827, 1.89626483, 4.17364243, 2.80075231,
#        1.53905288, 2.29658394, 4.53156702, 1.39763106, 5.02139126,
#        2.56118207, 1.19938362, 4.27778046, 1.35074138, 3.66981303,
#        3.67443451, 1.8631922 , 3.52327343, 5.41344784, 3.87577401,
#        2.34373699, 0.84406311, 3.73032167, 3.46086435, 3.93318495,
#        1.96254243, 1.71032948, 2.62316116, 1.26381131, 3.62249077,
#        3.4572278 , 3.33593855, 3.91562185, 2.61290045, 2.94377589,
# ...

# %%
sns.histplot(data=df, kde=True, color='b')
# Out:
# <Axes: ylabel='Count'>

# %%
rs = np.random.RandomState(10)
data = rs.normal(size=100)
sns.displot(data=data, kde=True, bins=10, rug=True)

# %%
data = sns.load_dataset('penguins')
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data=data, x='body_mass_g', kde=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=data, x='body_mass_g', kde=True, hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=data, x='body_mass_g', kde=True, discrete=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
data = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data['total_bill'], kde=True)

# %%
data = sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=data, x='total_bill', y='tip', col='time')

# %%
data = sns.load_dataset('iris')
data.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.lineplot(x='sepal_length', y='sepal_width', data=data)
plt.title('Iris Dataset')
plt.xlim(5) # x starts from 5
sns.set_style('dark')

# %%
sns.set_style('darkgrid')
sns.lineplot(data=data, x='sepal_length', y='sepal_width')
plt.show()

# %%
sns.lineplot(data=data, x='sepal_length', y='sepal_width')
sns.set_style('white')
sns.despine() # remove boundaries of axes 
plt.figure(figsize=(8,12))
plt.show()

# %%
sns.lineplot(data=data, x='sepal_length', y='sepal_width')
sns.set_context(context='talk') # it only changes size of lebel but doesn't change overall style
plt.show()

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint', y='signal', hue='region', style='event', data=fmri)
plt.show()

# %%
data = sns.load_dataset("tips")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x='total_bill', y='tip', data=data, hue='smoker', style='time')
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
color = sns.color_palette('viridis')
sns.palplot(color)

# %%
color = sns.color_palette('Reds', 10)
sns.palplot(color)

# %%
data = sns.load_dataset('iris')
#sns.set_context('notebook')
def plot():
    sns.lineplot(data=data, x='sepal_length', y='sepal_width')

with sns.axes_style('whitegrid'):
    plt.subplot(2,1,1)
    sns.set_palette('Accent')
    plot()
plt.subplot(2,1,2)
sns.set_palette('vlag')
plot()
plt.show()

# %%
fig = plt.figure(figsize=(5,4))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
plot()

ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
plot()

plt.show()

# %%
ax1 = plt.subplot2grid((6, 1), (0,0), rowspan=2, colspan=1)
plot()
ax2 = plt.subplot2grid((6, 1), (2,0), rowspan=2, colspan=1)
plot()
ax3 = plt.subplot2grid((6, 1), (4,0), rowspan=2, colspan=1)
plot()
