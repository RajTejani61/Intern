# %%
import nltk
from nltk import sent_tokenize, word_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sample = """
Narendra Damodardas Modi[a] (born 17 September 1950) is an Indian politician who has served as the prime minister of India since 2014. Modi was the chief minister of Gujarat from 2001 to 2014 and is the member of parliament (MP) for Varanasi. He is a member of the Bharatiya Janata Party (BJP) and of the Rashtriya Swayamsevak Sangh (RSS), a right-wing Hindutva paramilitary volunteer organisation. He is the longest-serving prime minister outside the Indian National Congress.

Modi was born and raised in Vadnagar, Bombay State (present-day Gujarat), where he completed his secondary education. He was introduced to the RSS at the age of eight, becoming a full-time worker for the organisation in Gujarat in 1971. The RSS assigned him to the BJP in 1985, and he rose through the party hierarchy, becoming general secretary in 1998.[b] In 2001, Modi was appointed chief minister of Gujarat and elected to the legislative assembly soon after. His administration is considered complicit in the 2002 Gujarat riots[c] and has been criticised for its management of the crisis. According to official records, a little over 1,000 people were killed, three-quarters of whom were Muslim; independent sources estimated 2,000 deaths, mostly Muslim.[4] A Special Investigation Team appointed by the Supreme Court of India in 2012 found no evidence to initiate prosecution proceedings against him.[d] While his policies as chief minister were credited for encouraging economic growth, his administration was criticised for failing to significantly improve health, poverty and education indices in the state.[e]

In the 2014 Indian general election, Modi led the BJP to a parliamentary majority, the first for a party since 1984. His administration increased direct foreign investment and reduced spending on healthcare, education, and social-welfare programs. Modi began a high-profile sanitation campaign and weakened or abolished environmental and labour laws. His demonetisation of banknotes in 2016 and introduction of the Goods and Services Tax in 2017 sparked controversy. Modi's administration launched the 2019 Balakot airstrike against an alleged terrorist training camp in Pakistan; the airstrike failed,[5][6] but the action had nationalist appeal.[7] Modi's party won the 2019 general election which followed. In its second term, his administration revoked the special status of Jammu and Kashmir and introduced the Citizenship Amendment Act, prompting widespread protests and spurring the 2020 Delhi riots in which Muslims were brutalised and killed by Hindu mobs.[8][9][10] Three controversial farm laws led to sit-ins by farmers across the country, eventually causing their formal repeal. Modi oversaw India's response to the COVID-19 pandemic, during which, according to the World Health Organization, 4.7 million Indians died.[11][12] In the 2024 general election, Modi's party lost its majority in the lower house of Parliament and formed a government leading the National Democratic Alliance coalition. Following a terrorist attack in Indian-administered Jammu and Kashmir, Modi presided over the 2025 India–Pakistan conflict, which resulted in a ceasefire.
"""

# %% [markdown]
# ### Converting paragraph into Lines

# %%
paragraph = sent_tokenize(sample)
paragraph
# Out:
# ['\nNarendra Damodardas Modi[a] (born 17 September 1950) is an Indian politician who has served as the prime minister of India since 2014.',
#  'Modi was the chief minister of Gujarat from 2001 to 2014 and is the member of parliament (MP) for Varanasi.',
#  'He is a member of the Bharatiya Janata Party (BJP) and of the Rashtriya Swayamsevak Sangh (RSS), a right-wing Hindutva paramilitary volunteer organisation.',
#  'He is the longest-serving prime minister outside the Indian National Congress.',
#  'Modi was born and raised in Vadnagar, Bombay State (present-day Gujarat), where he completed his secondary education.',
#  'He was introduced to the RSS at the age of eight, becoming a full-time worker for the organisation in Gujarat in 1971.',
#  'The RSS assigned him to the BJP in 1985, and he rose through the party hierarchy, becoming general secretary in 1998.',
#  '[b] In 2001, Modi was appointed chief minister of Gujarat and elected to the legislative assembly soon after.',
#  'His administration is considered complicit in the 2002 Gujarat riots[c] and has been criticised for its management of the crisis.',
#  'According to official records, a little over 1,000 people were killed, three-quarters of whom were Muslim; independent sources estimated 2,000 deaths, mostly Muslim.',
#  '[4] A Special Investigation Team appointed by the Supreme Court of India in 2012 found no evidence to initiate prosecution proceedings against him.',
#  '[d] While his policies as chief minister were credited for encouraging economic growth, his administration was criticised for failing to significantly improve health, poverty and education indices in the state.',
#  '[e]\n\nIn the 2014 Indian general election, Modi led the BJP to a parliamentary majority, the first for a party since 1984.',
#  'His administration increased direct foreign investment and reduced spending on healthcare, education, and social-welfare programs.',
#  'Modi began a high-profile sanitation campaign and weakened or abolished environmental and labour laws.',
#  'His demonetisation of banknotes in 2016 and introduction of the Goods and Services Tax in 2017 sparked controversy.',
#  "Modi's administration launched the 2019 Balakot airstrike against an alleged terrorist training camp in Pakistan; the airstrike failed,[5][6] but the action had nationalist appeal.",
#  "[7] Modi's party won the 2019 general election which followed.",
#  'In its second term, his administration revoked the special status of Jammu and Kashmir and introduced the Citizenship Amendment Act, prompting widespread protests and spurring the 2020 Delhi riots in which Muslims were brutalised and killed by Hindu mobs.',
#  '[8][9][10] Three controversial farm laws led to sit-ins by farmers across the country, eventually causing their formal repeal.',
#  "Modi oversaw India's response to the COVID-19 pandemic, during which, according to the World Health Organization, 4.7 million Indians died.",
#  "[11][12] In the 2024 general election, Modi's party lost its majority in the lower house of Parliament and formed a government leading the National Democratic Alliance coalition.",
#  'Following a terrorist attack in Indian-administered Jammu and Kashmir, Modi presided over the 2025 India–Pakistan conflict, which resulted in a ceasefire.']

# %%
res = sent_tokenize("Narendra modi. Elon Musk")
print(res)
# Out:
# ['Narendra modi.', 'Elon Musk']

# %%
word_tokenize("Narendra modi. Elon Musk")
# Out:
# ['Narendra', 'modi', '.', 'Elon', 'Musk']

# %% [markdown]
# ### Lines to Words

# %%
word_tokenize(sample)
# Out:
# ['Narendra',
#  'Damodardas',
#  'Modi',
#  '[',
#  'a',
#  ']',
#  '(',
#  'born',
#  '17',
#  'September',
#  '1950',
#  ')',
#  'is',
#  'an',
#  'Indian',
#  'politician',
#  'who',
#  'has',
#  'served',
#  'as',
#  'the',
#  'prime',
#  'minister',
#  'of',
#  'India',
#  'since',
#  '2014',
#  '.',
#  'Modi',
#  'was',
#  'the',
#  'chief',
#  'minister',
#  'of',
#  'Gujarat',
#  'from',
#  '2001',
#  'to',
#  '2014',
#  'and',
#  'is',
#  'the',
#  'member',
#  'of',
#  'parliament',
#  '(',
#  'MP',
#  ')',
#  'for',
#  'Varanasi',
#  '.',
#  'He',
#  'is',
#  'a',
#  'member',
#  'of',
#  'the',
#  'Bharatiya',
#  'Janata',
#  'Party',
#  '(',
#  'BJP',
#  ')',
#  'and',
#  'of',
#  'the',
#  'Rashtriya',
#  'Swayamsevak',
#  'Sangh',
#  '(',
#  'RSS',
#  ')',
#  ',',
#  'a',
#  'right-wing',
#  'Hindutva',
#  'paramilitary',
#  'volunteer',
#  'organisation',
#  '.',
#  'He',
#  'is',
#  'the',
#  'longest-serving',
#  'prime',
#  'minister',
#  'outside',
#  'the',
#  'Indian',
#  'National',
#  'Congress',
#  '.',
#  'Modi',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Vadnagar',
#  ',',
#  'Bombay',
#  'State',
#  '(',
#  'present-day',
#  'Gujarat',
#  ')',
#  ',',
#  'where',
#  'he',
#  'completed',
#  'his',
#  'secondary',
#  'education',
#  '.',
#  'He',
#  'was',
#  'introduced',
#  'to',
#  'the',
#  'RSS',
#  'at',
#  'the',
#  'age',
#  'of',
#  'eight',
#  ',',
#  'becoming',
#  'a',
#  'full-time',
#  'worker',
#  'for',
#  'the',
#  'organisation',
#  'in',
#  'Gujarat',
#  'in',
#  '1971',
#  '.',
#  'The',
#  'RSS',
#  'assigned',
#  'him',
#  'to',
#  'the',
#  'BJP',
#  'in',
#  '1985',
#  ',',
#  'and',
#  'he',
#  'rose',
#  'through',
#  'the',
#  'party',
#  'hierarchy',
#  ',',
#  'becoming',
#  'general',
#  'secretary',
#  'in',
#  '1998',
#  '.',
#  '[',
#  'b',
#  ']',
#  'In',
#  '2001',
#  ',',
#  'Modi',
#  'was',
#  'appointed',
#  'chief',
#  'minister',
#  'of',
#  'Gujarat',
#  'and',
#  'elected',
#  'to',
#  'the',
#  'legislative',
#  'assembly',
#  'soon',
#  'after',
#  '.',
#  'His',
#  'administration',
#  'is',
#  'considered',
#  'complicit',
#  'in',
#  'the',
#  '2002',
#  'Gujarat',
#  'riots',
#  '[',
#  'c',
#  ']',
#  'and',
#  'has',
#  'been',
#  'criticised',
#  'for',
#  'its',
#  'management',
#  'of',
#  'the',
#  'crisis',
#  '.',
#  'According',
#  'to',
#  'official',
#  'records',
#  ',',
#  'a',
#  'little',
#  'over',
#  '1,000',
#  'people',
#  'were',
#  'killed',
#  ',',
#  'three-quarters',
#  'of',
#  'whom',
#  'were',
#  'Muslim',
#  ';',
#  'independent',
#  'sources',
#  'estimated',
#  '2,000',
#  'deaths',
#  ',',
#  'mostly',
#  'Muslim',
#  '.',
#  '[',
#  '4',
#  ']',
#  'A',
#  'Special',
#  'Investigation',
#  'Team',
#  'appointed',
#  'by',
#  'the',
#  'Supreme',
#  'Court',
#  'of',
#  'India',
#  'in',
#  '2012',
#  'found',
#  'no',
#  'evidence',
#  'to',
#  'initiate',
#  'prosecution',
#  'proceedings',
#  'against',
#  'him',
#  '.',
#  '[',
#  'd',
#  ']',
#  'While',
#  'his',
#  'policies',
#  'as',
#  'chief',
#  'minister',
#  'were',
#  'credited',
#  'for',
#  'encouraging',
#  'economic',
#  'growth',
#  ',',
#  'his',
#  'administration',
#  'was',
#  'criticised',
#  'for',
#  'failing',
#  'to',
#  'significantly',
#  'improve',
#  'health',
#  ',',
#  'poverty',
#  'and',
#  'education',
#  'indices',
#  'in',
#  'the',
#  'state',
#  '.',
#  '[',
#  'e',
#  ']',
#  'In',
#  'the',
#  '2014',
#  'Indian',
#  'general',
#  'election',
#  ',',
#  'Modi',
#  'led',
#  'the',
#  'BJP',
#  'to',
#  'a',
#  'parliamentary',
#  'majority',
#  ',',
#  'the',
#  'first',
#  'for',
#  'a',
#  'party',
#  'since',
#  '1984',
#  '.',
#  'His',
#  'administration',
#  'increased',
#  'direct',
#  'foreign',
#  'investment',
#  'and',
#  'reduced',
#  'spending',
#  'on',
#  'healthcare',
#  ',',
#  'education',
#  ',',
#  'and',
#  'social-welfare',
#  'programs',
#  '.',
#  'Modi',
#  'began',
#  'a',
#  'high-profile',
#  'sanitation',
#  'campaign',
#  'and',
#  'weakened',
#  'or',
#  'abolished',
#  'environmental',
#  'and',
#  'labour',
#  'laws',
#  '.',
#  'His',
#  'demonetisation',
#  'of',
#  'banknotes',
#  'in',
#  '2016',
#  'and',
#  'introduction',
#  'of',
#  'the',
#  'Goods',
#  'and',
#  'Services',
#  'Tax',
#  'in',
#  '2017',
#  'sparked',
#  'controversy',
#  '.',
#  'Modi',
#  "'s",
#  'administration',
#  'launched',
#  'the',
#  '2019',
#  'Balakot',
#  'airstrike',
#  'against',
#  'an',
#  'alleged',
#  'terrorist',
#  'training',
#  'camp',
#  'in',
#  'Pakistan',
#  ';',
#  'the',
#  'airstrike',
#  'failed',
#  ',',
#  '[',
#  '5',
#  ']',
#  '[',
#  '6',
#  ']',
#  'but',
#  'the',
#  'action',
#  'had',
#  'nationalist',
#  'appeal',
#  '.',
#  '[',
#  '7',
#  ']',
#  'Modi',
#  "'s",
#  'party',
#  'won',
#  'the',
#  '2019',
#  'general',
#  'election',
#  'which',
#  'followed',
#  '.',
#  'In',
#  'its',
#  'second',
#  'term',
#  ',',
#  'his',
#  'administration',
#  'revoked',
#  'the',
#  'special',
#  'status',
#  'of',
#  'Jammu',
#  'and',
#  'Kashmir',
#  'and',
#  'introduced',
#  'the',
#  'Citizenship',
#  'Amendment',
#  'Act',
#  ',',
#  'prompting',
#  'widespread',
#  'protests',
#  'and',
#  'spurring',
#  'the',
#  '2020',
#  'Delhi',
#  'riots',
#  'in',
#  'which',
#  'Muslims',
#  'were',
#  'brutalised',
#  'and',
#  'killed',
#  'by',
#  'Hindu',
#  'mobs',
#  '.',
#  '[',
#  '8',
#  ']',
#  '[',
#  '9',
#  ']',
#  '[',
#  '10',
#  ']',
#  'Three',
#  'controversial',
#  'farm',
#  'laws',
#  'led',
#  'to',
#  'sit-ins',
#  'by',
#  'farmers',
#  'across',
#  'the',
#  'country',
#  ',',
#  'eventually',
#  'causing',
#  'their',
#  'formal',
#  'repeal',
#  '.',
#  'Modi',
#  'oversaw',
#  'India',
#  "'s",
#  'response',
#  'to',
#  'the',
#  'COVID-19',
#  'pandemic',
#  ',',
#  'during',
#  'which',
#  ',',
#  'according',
#  'to',
#  'the',
#  'World',
#  'Health',
#  'Organization',
#  ',',
#  '4.7',
#  'million',
#  'Indians',
#  'died',
#  '.',
#  '[',
#  '11',
#  ']',
#  '[',
#  '12',
#  ']',
#  'In',
#  'the',
#  '2024',
#  'general',
#  'election',
#  ',',
#  'Modi',
#  "'s",
#  'party',
#  'lost',
#  'its',
#  'majority',
#  'in',
#  'the',
#  'lower',
#  'house',
#  'of',
#  'Parliament',
#  'and',
#  'formed',
#  'a',
#  'government',
#  'leading',
#  'the',
#  'National',
#  'Democratic',
#  'Alliance',
#  'coalition',
#  '.',
#  'Following',
#  'a',
#  'terrorist',
#  'attack',
#  'in',
#  'Indian-administered',
#  'Jammu',
#  'and',
#  'Kashmir',
#  ',',
#  'Modi',
#  'presided',
#  'over',
#  'the',
#  '2025',
#  'India–Pakistan',
#  'conflict',
#  ',',
#  'which',
#  'resulted',
#  'in',
#  'a',
#  'ceasefire',
#  '.']

# %%
from nltk import WordPunctTokenizer

tokenizer = WordPunctTokenizer() # based on punchuation
tokenizer.tokenize("Let's see how it's working.")
# Out:
# ['Let', "'", 's', 'see', 'how', 'it', "'", 's', 'working', '.']

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+') # based on regular expression/ pattern
text = "Let's see how it's working."
tokenizer.tokenize(text)
# Out:
# ['Let', 's', 'see', 'how', 'it', 's', 'working']

# %% [markdown]
# ### bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range=(3, 3)) # n-gram convets data into provided range vector
vectorizer.fit_transform(paragraph)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 427 stored elements and shape (23, 423)>

# %%
vectorizer.vocabulary_
# Out:
# {'narendra damodardas modi': 258,
#  'damodardas modi born': 104,
#  'modi born 17': 246,
#  'born 17 september': 80,
#  '17 september 1950': 5,
#  'september 1950 is': 328,
#  '1950 is an': 7,
#  'is an indian': 210,
#  'an indian politician': 41,
#  'indian politician who': 201,
#  'politician who has': 298,
#  'who has served': 416,
#  'has served as': 154,
#  'served as the': 329,
#  'as the prime': 64,
#  'the prime minister': 376,
#  'prime minister of': 302,
#  'minister of india': 241,
#  'of india since': 266,
#  'india since 2014': 197,
#  'modi was the': 254,
#  'was the chief': 405,
#  'the chief minister': 362,
#  'chief minister of': 90,
#  'minister of gujarat': 240,
#  'of gujarat from': 264,
#  'gujarat from 2001': 148,
#  'from 2001 to': 139,
#  '2001 to 2014': 10,
#  'to 2014 and': 388,
#  '2014 and is': 13,
#  'and is the': 49,
#  'is the member': 214,
#  'the member of': 372,
#  'member of parliament': 237,
#  'of parliament mp': 269,
#  'parliament mp for': 289,
#  'mp for varanasi': 255,
#  'he is member': 156,
#  'is member of': 212,
#  'member of the': 238,
#  'of the bharatiya': 270,
#  'the bharatiya janata': 359,
#  'bharatiya janata party': 75,
#  'janata party bjp': 219,
#  'party bjp and': 291,
#  'bjp and of': 76,
#  'and of the': 54,
#  'of the rashtriya': 273,
#  'the rashtriya swayamsevak': 377,
#  'rashtriya swayamsevak sangh': 311,
#  'swayamsevak sangh rss': 343,
#  'sangh rss right': 324,
#  'rss right wing': 323,
#  'right wing hindutva': 317,
#  'wing hindutva paramilitary': 419,
#  'hindutva paramilitary volunteer': 166,
#  'paramilitary volunteer organisation': 287,
#  'he is the': 157,
#  'is the longest': 213,
#  'the longest serving': 370,
#  'longest serving prime': 231,
#  'serving prime minister': 331,
#  'prime minister outside': 303,
#  'minister outside the': 242,
#  'outside the indian': 280,
#  'the indian national': 368,
#  'indian national congress': 200,
#  'modi was born': 253,
#  'was born and': 402,
#  'born and raised': 81,
#  'and raised in': 55,
#  'raised in vadnagar': 310,
#  'in vadnagar bombay': 190,
#  'vadnagar bombay state': 400,
#  'bombay state present': 79,
#  'state present day': 340,
#  'present day gujarat': 300,
#  'day gujarat where': 105,
#  'gujarat where he': 151,
#  'where he completed': 411,
#  'he completed his': 155,
#  'completed his secondary': 93,
#  'his secondary education': 173,
#  'he was introduced': 159,
#  'was introduced to': 404,
#  'introduced to the': 206,
#  'to the rss': 397,
#  'the rss at': 379,
#  'rss at the': 322,
#  'at the age': 67,
#  'the age of': 357,
#  'age of eight': 35,
#  'of eight becoming': 262,
#  'eight becoming full': 115,
#  'becoming full time': 71,
#  'full time worker': 140,
#  'time worker for': 387,
#  'worker for the': 421,
#  'for the organisation': 135,
#  'the organisation in': 374,
#  'organisation in gujarat': 278,
#  'in gujarat in': 181,
#  'gujarat in 1971': 149,
#  'the rss assigned': 378,
#  'rss assigned him': 321,
#  'assigned him to': 66,
#  'him to the': 165,
#  'to the bjp': 394,
#  'the bjp in': 360,
#  'bjp in 1985': 77,
#  'in 1985 and': 176,
#  '1985 and he': 8,
#  'and he rose': 46,
#  'he rose through': 158,
#  'rose through the': 320,
#  'through the party': 386,
#  'the party hierarchy': 375,
#  'party hierarchy becoming': 292,
#  'hierarchy becoming general': 163,
#  'becoming general secretary': 72,
#  'general secretary in': 143,
#  'secretary in 1998': 327,
#  'in 2001 modi': 177,
#  '2001 modi was': 9,
#  'modi was appointed': 252,
#  'was appointed chief': 401,
#  'appointed chief minister': 62,
#  'of gujarat and': 263,
#  'gujarat and elected': 147,
#  'and elected to': 43,
#  'elected to the': 116,
#  'to the legislative': 396,
#  'the legislative assembly': 369,
#  'legislative assembly soon': 229,
#  'assembly soon after': 65,
#  'his administration is': 168,
#  'administration is considered': 30,
#  'is considered complicit': 211,
#  'considered complicit in': 96,
#  'complicit in the': 94,
#  'in the 2002': 185,
#  'the 2002 gujarat': 349,
#  '2002 gujarat riots': 11,
#  'gujarat riots and': 150,
#  'riots and has': 318,
#  'and has been': 45,
#  'has been criticised': 153,
#  'been criticised for': 73,
#  'criticised for its': 103,
#  'for its management': 133,
#  'its management of': 216,
#  'management of the': 236,
#  'of the crisis': 271,
#  'according to official': 23,
#  'to official records': 390,
#  'official records little': 275,
#  'records little over': 312,
#  'little over 000': 230,
#  'over 000 people': 281,
#  '000 people were': 1,
#  'people were killed': 296,
#  'were killed three': 409,
#  'killed three quarters': 223,
#  'three quarters of': 385,
#  'quarters of whom': 309,
#  'of whom were': 274,
#  'whom were muslim': 417,
#  'were muslim independent': 410,
#  'muslim independent sources': 256,
#  'independent sources estimated': 193,
#  'sources estimated 000': 335,
#  'estimated 000 deaths': 122,
#  '000 deaths mostly': 0,
#  'deaths mostly muslim': 106,
#  'special investigation team': 336,
#  'investigation team appointed': 208,
#  'team appointed by': 345,
#  'appointed by the': 61,
#  'by the supreme': 86,
#  'the supreme court': 381,
#  'supreme court of': 342,
#  'court of india': 99,
#  'of india in': 265,
#  'india in 2012': 194,
#  'in 2012 found': 178,
#  '2012 found no': 12,
#  'found no evidence': 138,
#  'no evidence to': 260,
#  'evidence to initiate': 124,
#  'to initiate prosecution': 389,
#  'initiate prosecution proceedings': 203,
#  'prosecution proceedings against': 307,
#  'proceedings against him': 304,
#  'while his policies': 415,
#  'his policies as': 172,
#  'policies as chief': 297,
#  'as chief minister': 63,
#  'chief minister were': 91,
#  'minister were credited': 243,
#  'were credited for': 408,
#  'credited for encouraging': 101,
#  'for encouraging economic': 131,
#  'encouraging economic growth': 120,
#  'economic growth his': 112,
#  'growth his administration': 146,
#  'his administration was': 170,
#  'administration was criticised': 33,
#  'was criticised for': 403,
#  'criticised for failing': 102,
#  'for failing to': 132,
#  'failing to significantly': 126,
#  'to significantly improve': 392,
#  'significantly improve health': 332,
#  'improve health poverty': 175,
#  'health poverty and': 161,
#  'poverty and education': 299,
#  'and education indices': 42,
#  'education indices in': 114,
#  'indices in the': 202,
#  'in the state': 189,
#  'in the 2014': 186,
#  'the 2014 indian': 350,
#  '2014 indian general': 14,
#  'indian general election': 199,
#  'general election modi': 141,
#  'election modi led': 117,
#  'modi led the': 247,
#  'led the bjp': 227,
#  'the bjp to': 361,
#  'bjp to parliamentary': 78,
#  'to parliamentary majority': 391,
#  'parliamentary majority the': 290,
#  'majority the first': 235,
#  'the first for': 366,
#  'first for party': 129,
#  'for party since': 134,
#  'party since 1984': 294,
#  'his administration increased': 167,
#  'administration increased direct': 29,
#  'increased direct foreign': 192,
#  'direct foreign investment': 110,
#  'foreign investment and': 136,
#  'investment and reduced': 209,
#  'and reduced spending': 56,
#  'reduced spending on': 313,
#  'spending on healthcare': 338,
#  'on healthcare education': 276,
#  'healthcare education and': 162,
#  'education and social': 113,
#  'and social welfare': 58,
#  'social welfare programs': 334,
#  'modi began high': 245,
#  'began high profile': 74,
#  'high profile sanitation': 164,
#  'profile sanitation campaign': 305,
#  'sanitation campaign and': 325,
#  'campaign and weakened': 88,
#  'and weakened or': 60,
#  'weakened or abolished': 406,
#  'or abolished environmental': 277,
#  'abolished environmental and': 22,
#  'environmental and labour': 121,
#  'and labour laws': 53,
#  'his demonetisation of': 171,
#  'demonetisation of banknotes': 109,
#  'of banknotes in': 261,
#  'banknotes in 2016': 70,
#  'in 2016 and': 179,
#  '2016 and introduction': 15,
#  'and introduction of': 48,
#  'introduction of the': 207,
#  'of the goods': 272,
#  'the goods and': 367,
#  'goods and services': 144,
#  'and services tax': 57,
#  'services tax in': 330,
#  'tax in 2017': 344,
#  'in 2017 sparked': 180,
#  '2017 sparked controversy': 16,
#  'modi administration launched': 244,
#  'administration launched the': 31,
#  'launched the 2019': 224,
#  'the 2019 balakot': 351,
#  '2019 balakot airstrike': 17,
#  'balakot airstrike against': 69,
#  'airstrike against an': 36,
#  'against an alleged': 34,
#  'an alleged terrorist': 40,
#  'alleged terrorist training': 38,
#  'terrorist training camp': 348,
#  'training camp in': 399,
#  'camp in pakistan': 87,
#  'in pakistan the': 184,
#  'pakistan the airstrike': 285,
#  'the airstrike failed': 358,
#  'airstrike failed but': 37,
#  'failed but the': 125,
#  'but the action': 83,
#  'the action had': 356,
#  'action had nationalist': 27,
#  'had nationalist appeal': 152,
#  'modi party won': 250,
#  'party won the': 295,
#  'won the 2019': 420,
#  'the 2019 general': 352,
#  '2019 general election': 18,
#  'general election which': 142,
#  'election which followed': 119,
#  'in its second': 183,
#  'its second term': 217,
#  'second term his': 326,
#  'term his administration': 346,
#  'his administration revoked': 169,
#  'administration revoked the': 32,
#  'revoked the special': 316,
#  'the special status': 380,
#  'special status of': 337,
#  'status of jammu': 341,
#  'of jammu and': 267,
#  'jammu and kashmir': 218,
#  'and kashmir and': 50,
#  'kashmir and introduced': 220,
#  'and introduced the': 47,
#  'introduced the citizenship': 205,
#  'the citizenship amendment': 363,
#  'citizenship amendment act': 92,
#  'amendment act prompting': 39,
#  'act prompting widespread': 26,
#  'prompting widespread protests': 306,
#  'widespread protests and': 418,
#  'protests and spurring': 308,
#  'and spurring the': 59,
#  'spurring the 2020': 339,
#  'the 2020 delhi': 353,
#  '2020 delhi riots': 19,
#  'delhi riots in': 107,
#  'riots in which': 319,
#  'in which muslims': 191,
#  'which muslims were': 413,
#  'muslims were brutalised': 257,
#  'were brutalised and': 407,
#  'brutalised and killed': 82,
#  'and killed by': 52,
#  'killed by hindu': 222,
#  'by hindu mobs': 85,
#  '10 three controversial': 2,
#  'three controversial farm': 384,
#  'controversial farm laws': 97,
#  'farm laws led': 127,
#  'laws led to': 225,
#  'led to sit': 228,
#  'to sit ins': 393,
#  'sit ins by': 333,
#  'ins by farmers': 204,
#  'by farmers across': 84,
#  'farmers across the': 128,
#  'across the country': 25,
#  'the country eventually': 364,
#  'country eventually causing': 98,
#  'eventually causing their': 123,
#  'causing their formal': 89,
#  'their formal repeal': 383,
#  'modi oversaw india': 248,
#  'oversaw india response': 283,
#  'india response to': 196,
#  'response to the': 314,
#  'to the covid': 395,
#  'the covid 19': 365,
#  'covid 19 pandemic': 100,
#  '19 pandemic during': 6,
#  'pandemic during which': 286,
#  'during which according': 111,
#  'which according to': 412,
#  'according to the': 24,
#  'to the world': 398,
#  'the world health': 382,
#  'world health organization': 422,
#  'health organization million': 160,
#  'organization million indians': 279,
#  'million indians died': 239,
#  '11 12 in': 3,
#  '12 in the': 4,
#  'in the 2024': 187,
#  'the 2024 general': 354,
#  '2024 general election': 20,
#  'election modi party': 118,
#  'modi party lost': 249,
#  'party lost its': 293,
#  'lost its majority': 232,
#  'its majority in': 215,
#  'majority in the': 234,
#  'in the lower': 188,
#  'the lower house': 371,
#  'lower house of': 233,
#  'house of parliament': 174,
#  'of parliament and': 268,
#  'parliament and formed': 288,
#  'and formed government': 44,
#  'formed government leading': 137,
#  'government leading the': 145,
#  'leading the national': 226,
#  'the national democratic': 373,
#  'national democratic alliance': 259,
#  'democratic alliance coalition': 108,
#  'following terrorist attack': 130,
#  'terrorist attack in': 347,
#  'attack in indian': 68,
#  'in indian administered': 182,
#  'indian administered jammu': 198,
#  'administered jammu and': 28,
#  'and kashmir modi': 51,
#  'kashmir modi presided': 221,
#  'modi presided over': 251,
#  'presided over the': 301,
#  'over the 2025': 282,
#  'the 2025 india': 355,
#  '2025 india pakistan': 21,
#  'india pakistan conflict': 195,
#  'pakistan conflict which': 284,
#  'conflict which resulted': 95,
#  'which resulted in': 414,
#  'resulted in ceasefire': 315}

# %%
print(paragraph[0])
# Out:
# Narendra Damodardas Modi[a] (born 17 September 1950) is an Indian politician who has served as the prime minister of India since 2014.
