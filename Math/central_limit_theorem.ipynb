# %% [markdown]
# You are data analyst at a tech company. Users around the world have different web page load times, usually being biased based on network speed and location. you need to estimate the mean load time but it is impractical to verify every user. Instead of analyzing all user , you take a small sample (e.g., 50 users) to estimate the average load time. But since the data isn’t normally distributed, can you trust this average? This is where the Central Limit Theorem comes into play.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.exponential(scale=2, size=100000)

# %%
sample_size = 50
no_of_trails = 1000
sample_mean = []

# %%
for _ in range(no_of_trails):
    samples = np.random.choice(data, size=sample_size)
    sample_mean.append(np.mean(samples))

plt.hist(sample_mean, bins=50, color='skyblue', edgecolor='black')
plt.title("Sampling distribution of page load time (Means)")
plt.xlabel("Sample mean Load Time")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
