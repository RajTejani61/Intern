# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
image = img.imread('C:/Users/admin/Intern/1382553.png')
plt.imshow(image)
plt.show()

# %%
print(image.size)
print(image.shape)
print(image)
# Out:
# 28532736
# (2304, 4128, 3)
# [[[0.24313726 0.28235295 0.36862746]
#   [0.19215687 0.22745098 0.34117648]
#   [0.22745098 0.27058825 0.3647059 ]
#   ...
#   [0.6784314  0.7490196  0.8156863 ]
#   [0.6862745  0.77254903 0.8117647 ]
#   [0.6392157  0.6862745  0.7254902 ]]
#
#  [[0.20784314 0.26666668 0.35686275]
#   [0.25882354 0.32156864 0.42352942]
#   [0.23529412 0.29803923 0.38039216]
#   ...
#   [0.627451   0.6901961  0.7921569 ]
#   [0.6745098  0.7411765  0.8039216 ]
#   [0.7372549  0.8039216  0.827451  ]]
#
#  [[0.23529412 0.28235295 0.3529412 ]
#   [0.25490198 0.30980393 0.3882353 ]
#   [0.15294118 0.2        0.2901961 ]
#   ...
#   [0.7058824  0.8235294  0.9019608 ]
#   [0.6431373  0.7176471  0.79607844]
#   [0.69411767 0.7294118  0.7882353 ]]
#
#  ...
#
#  [[0.19607843 0.25490198 0.38431373]
#   [0.21960784 0.2784314  0.4       ]
#   [0.29803923 0.3647059  0.46666667]
#   ...
#   [0.30588236 0.35686275 0.44705883]
#   [0.41568628 0.50980395 0.56078434]
# ...

# %%
modifiedImg = image[:, :, 0]
plt.imshow(modifiedImg)
plt.show()

# %%
modifiedImg = image[1500:2000, 2000:4000, 2]
plt.imshow(modifiedImg)
plt.show()

# %%
modifiedImg = image[:,:,0]
plt.imshow(modifiedImg, cmap='hot')
plt.show()

# %%
x = [1000, 3000]
y = [4000, 100]

plt.plot(x, y, color='white', linewidth=3)
plt.imshow(modifiedImg)
plt.show()

# %%
# area of img
height, width, _ = image.shape
area = height * width
print(area)
# Out:
# 9510912
